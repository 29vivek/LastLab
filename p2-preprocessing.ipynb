# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../P2_mov.csv')

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
df.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df['profit']=df['revenue']-df['budget']
colms = ['budget','genres','original_language','title','overview','release_date','runtime','status','vote_average','profit']
df2 = df[colms]

# %%
df2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#      original_language                                     title  \
# 0                   en                                    Avatar
# ...

# %%
df2.isna().sum()
# Out:
# budget               0
# genres               0
# original_language    0
# title                0
# overview             3
# release_date         1
# runtime              2
# status               0
# vote_average         0
# profit               0
# dtype: int64

# %%
df2.shape
# Out:
# (4803, 10)

# %%
df2.dtypes
# Out:
# budget                 int64
# genres                object
# original_language     object
# title                 object
# overview              object
# release_date          object
# runtime              float64
# status                object
# vote_average         float64
# profit                 int64
# dtype: object

# %%
df2.isna().sum()
# Out:
# budget               0
# genres               0
# original_language    0
# title                0
# overview             3
# release_date         1
# runtime              2
# status               0
# vote_average         0
# profit               0
# dtype: int64

# %%
df2[pd.isna(df['overview'])]
# Out:
#         budget                               genres original_language  \
# 2656  15000000        [{"id": 18, "name": "Drama"}]                it
# 4140         2  [{"id": 99, "name": "Documentary"}]                en
# 4431    913000  [{"id": 99, "name": "Documentary"}]                de
#
#                                            title overview release_date  \
# 2656  Chiamatemi Francesco - Il Papa della gente      NaN   2015-12-03
# 4140                 To Be Frank, Sinatra at 100      NaN   2015-12-12
# 4431                                 Food Chains      NaN   2014-04-26
#
#       runtime    status  vote_average    profit
# 2656      NaN  Released           7.3 -15000000
# 4140      NaN  Released           0.0        -2
# 4431     83.0  Released           7.4   -913000

# %%
df2['overview'].fillna('null',inplace=True)

# %%
df2['runtime'].fillna(df['runtime'].mean() ,inplace=True)

# %%
del(df2['release_date'])

# %%
df2.isna().sum()
# Out:
# budget               0
# genres               0
# original_language    0
# title                0
# overview             0
# runtime              0
# status               0
# vote_average         0
# profit               0
# dtype: int64

# %%
df2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#      original_language                                     title  \
# 0                   en                                    Avatar
# ...

# %%
df2['status']=df2.apply(lambda row: "Hit" if (row['vote_average']>=6) else "Flop", axis=1)
# df2['status']=np.where(df2['vote_average']>=6 , 'hit','flop')
# Out:
# <ipython-input-36-2fc336822f24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['status']=df2.apply(lambda row: "Hit" if (row['vote_average']>=6) else "Flop", axis=1)

# %%
df2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#      original_language                                     title  \
# 0                   en                                    Avatar
# ...

# %%
df2['budget']=((df2['budget']-df2['budget'].min())/(df2['budget'].max()-df2['budget'].min()))*100
# Out:
# <ipython-input-38-ace6194f39d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['budget']=((df2['budget']-df2['budget'].min())/(df2['budget'].max()-df2['budget'].min()))*100

# %%
df2['budget']
# Out:
# 0       62.368421
# 1       78.947368
# 2       64.473684
# 3       65.789474
# 4       68.421053
#           ...
# 4798     0.057895
# 4799     0.002368
# 4800     0.000000
# 4801     0.000000
# 4802     0.000000
# Name: budget, Length: 4803, dtype: float64

# %%
df2['profit']=((df2['profit']-df2['profit'].min())/(df2['profit'].max()-df2['profit'].min()))*100
# Out:
# <ipython-input-43-74812dcdde14>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['profit']=((df2['profit']-df2['profit'].min())/(df2['profit'].max()-df2['profit'].min()))*100

# %%
df2.head()
# Out:
#       budget                                             genres  \
# 0  62.368421  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  78.947368  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  64.473684  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  65.789474  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  68.421053  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#   original_language                                     title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  runtime status  \
# 0  In the 22nd century, a paraplegic Marine is di...    162.0    Hit
# ...

# %%
dv=df2.corr()
dv
# Out:
#                 budget   runtime  vote_average    profit
# budget        1.000000  0.269834      0.093146  0.575852
# runtime       0.269834  1.000000      0.373989  0.219919
# vote_average  0.093146  0.373989      1.000000  0.208241
# profit        0.575852  0.219919      0.208241  1.000000

# %%
import seaborn as sn
sn.heatmap(dv , annot=True)
# Out:
# <AxesSubplot:>

# %%
x=np.array(df['budget'])
y=np.array(df['profit'])
plt.xlabel('budget')
plt.ylabel('profit')
plt.title("budget vs profit")
pt=plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
df2.plot.bar(x = 'budget', y = 'profit')
# Out:
# <AxesSubplot:xlabel='budget'>

# %%
dfp=pd.DataFrame({'budget':df2['budget'][0:10],'profit':df2['profit'][0:10]})

# %%
dfp.plot.bar(x='budget',y='profit')
# Out:
# <AxesSubplot:xlabel='budget'>

# %%
df3=pd.read_csv("../P1_movies_metadata.csv")
# Out:
# /home/vivek/miniconda3/envs/DSE/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df3.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df4=pd.merge(df[0:500],df3[0:500], on="original_title")

# %%
df4.head()
# Out:
#     budget_x                                           genres_x  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  175000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 2  175000000  [{"id": 10751, "name": "Family"}, {"id": 12, "...
# 3  115000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 4  100000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                       homepage_x    id_x  \
# 0                    http://www.avatarmovie.com/   19995
# 1                                            NaN    9804
# 2  http://movies.disney.com/the-jungle-book-2016  278927
# 3                                            NaN   36955
# 4                                            NaN     414
#
#                                             keywords original_language_x  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                  en
# 1  [{"id": 270, "name": "ocean"}, {"id": 331, "na...                  en
# ...
